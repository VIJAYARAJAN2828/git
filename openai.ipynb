# %%
import requests

API_KEY = "YOUR_API_KEY"

def get_weather_by_location(lat, lon):
    url = "https://api.openweathermap.org/data/2.5/weather"

    params = {
        "lat": lat,
        "lon": lon,
        "appid": API_KEY,
        "units": "metric"
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()

        weather_info = {
            "temperature_c": data["main"]["temp"],
            "feels_like_c": data["main"]["feels_like"],
            "humidity_percent": data["main"]["humidity"],
            "weather_condition": data["weather"][0]["main"],
            "description": data["weather"][0]["description"],
            "wind_speed_mps": data["wind"]["speed"],
            "city": data.get("name")
        }

        return weather_info
    else:
        return {
            "error": response.status_code,
            "message": response.text
        }

# %%
# Example: Chennai
latitude = 12.93662747697138
longitude = 77.68767365907163
weather = get_weather_by_location(latitude, longitude)
print(weather)
# Out:
# {'error': 401, 'message': '{"cod":401, "message": "Invalid API key. Please see https://openweathermap.org/faq#error401 for more info."}'}
